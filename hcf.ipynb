# %% [markdown]
# <a href="https://colab.research.google.com/github/pgupta25421-alt/Davis_lab_work/blob/main/hcf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## to find out output hcf
## input two number

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

#---------------------------------------------------------
if(num2 == 0):
  print("HCF :", num1)
else:
  while(num2 != 0):
    rem = num1 % num2
    num1 = num2
    num2 = rem
#---------------------------------------------------------
print("HCF:", num1)
# Out:
# Enter first number: 2
# Enter second number: 4
# HCF: 2
