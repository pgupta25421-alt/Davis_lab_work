# %% [markdown]
# <a href="https://colab.research.google.com/github/pgupta25421-alt/Davis_lab_work/blob/main/multiplication_table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to print multiplication table
def multiplication_table(number):
    if number < 0:
        print("Negative numbers are not allowed!")
        return  # exit the function if input is negative

    # Loop from 1 to 10
    for i in range(1, 11):
        print(f"{number} x {i} = {number * i}")

# Take input from user
num = int(input("Enter a number: "))
multiplication_table(num)
# Out:
# Enter a number: 18
# 18 x 1 = 18
# 18 x 2 = 36
# 18 x 3 = 54
# 18 x 4 = 72
# 18 x 5 = 90
# 18 x 6 = 108
# 18 x 7 = 126
# 18 x 8 = 144
# 18 x 9 = 162
# 18 x 10 = 180
