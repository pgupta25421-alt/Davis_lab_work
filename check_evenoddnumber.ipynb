# %% [markdown]
# <a href="https://colab.research.google.com/github/pgupta25421-alt/Davis_lab_work/blob/main/check_evenoddnumber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#write a program to check odd and even number
def check_odd_even(number):
  if number % 2 == 0:
    print("even")
  else:
    print("odd")
number = int(input("enter a number:"))
check_odd_even(number)
# Out:
# enter a number:4
# even
