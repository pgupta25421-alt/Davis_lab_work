# %% [markdown]
# <a href="https://colab.research.google.com/github/pgupta25421-alt/Davis_lab_work/blob/main/functionevenodd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_even_odd(num):
    if num % 2 == 0:
        return "Even Number"
    else:
        return "Odd Number"

# user se input from user
number = int(input("Enter a number: "))

# function call
result = check_even_odd(number)

print(result)
# Out:
# Enter a number: 5
# Odd Number
